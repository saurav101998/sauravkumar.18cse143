# %% [markdown]
# # Assignment 3

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
path="loan.csv"

# %%
import pandas as pd
data=pd.read_csv(path)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (500, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
# Loan_ID           500 non-null object
# loan_status       500 non-null object
# Principal         500 non-null int64
# terms             500 non-null int64
# effective_date    500 non-null object
# due_date          500 non-null object
# paid_off_time     400 non-null object
# past_due_days     200 non-null float64
# age               500 non-null int64
# education         500 non-null object
# Gender            500 non-null object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'loan_status', 'Principal', 'terms', 'effective_date',
#        'due_date', 'paid_off_time', 'past_due_days', 'age', 'education',
#        'Gender'],
#       dtype='object')

# %%
data.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
data.tail()
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male

# %%
data.head(5)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
data[['Principal',"age"]].head(10)
# Out:
#    Principal  age
# 0       1000   45
# 1       1000   50
# 2       1000   33
# 3       1000   27
# 4       1000   28
# 5        300   35
# 6       1000   29
# 7       1000   36
# 8       1000   28
# 9        800   26

# %%
data.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# past_due_days     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %%
data.shape
# Out:
# (100, 11)

# %%
data.head(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# 405  xqd20160406  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 406  xqd20160407  COLLECTION_PAIDOFF        800     15      9/10/2016
# 407  xqd20160408  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 408  xqd20110409  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 409  xqd20160410  COLLECTION_PAIDOFF       1000     15      9/10/2016
#
#       due_date     paid_off_time  past_due_days  age             education  \
# 400  10/8/2016  10/10/2016 11:45            2.0   26               college
# ...

# %%
data['Principal'].mean()
# Out:
# 957.0

# %%
data['Principal'].head()
# Out:
# 400    1000
# 401    1000
# 402    1000
# 403    1000
# 404     800
# Name: Principal, dtype: int64

# %%
data.head(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 400  xqd20160401  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 401  xqd20160402  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 402  xqd20320403  COLLECTION_PAIDOFF       1000     30       9/9/2016
# 403  xqd20160404  COLLECTION_PAIDOFF       1000     15       9/9/2016
# 404  xqd20190405  COLLECTION_PAIDOFF        800     15       9/9/2016
# 405  xqd20160406  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 406  xqd20160407  COLLECTION_PAIDOFF        800     15      9/10/2016
# 407  xqd20160408  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 408  xqd20110409  COLLECTION_PAIDOFF       1000     30      9/10/2016
# 409  xqd20160410  COLLECTION_PAIDOFF       1000     15      9/10/2016
#
#       due_date     paid_off_time  past_due_days  age             education  \
# 400  10/8/2016  10/10/2016 11:45            2.0   26               college
# ...

# %%
data['age'].mean()
# Out:
# 31.34

# %%
data["age"].head()
# Out:
# 400    26
# 401    28
# 402    39
# 403    29
# 404    33
# Name: age, dtype: int64

# %%
data[['age',"terms"]].head(20)
# Out:
#      age  terms
# 400   26     30
# 401   28     15
# 402   39     30
# 403   29     15
# 404   33     15
# 405   27     30
# 406   34     15
# 407   26     30
# 408   28     30
# 409   32     15
# 410   27     15
# 411   21     30
# 412   39     15
# 413   38     15
# 414   36     30
# 415   33     15
# 416   21     30
# 417   25     15
# 418   29     15
# 419   33     30
